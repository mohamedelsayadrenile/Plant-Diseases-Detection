# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the YOLO model
model = YOLO('/home/renile-ai/AI/Plant-Diseases-Detection/yolo11x_leaf.pt')

result = model.predict(
    '/home/renile-ai/AI/Plant-Diseases-Detection/potato_late.jpeg',
    task="detect",
    save=False,
    conf=0.15
)[0]

# Load the original image
image_path = result.path
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Annotate the image with predictions
annotated_image = result.plot()

# Display the annotated image
plt.figure(figsize=(10, 7))
plt.imshow(annotated_image)
plt.axis("off")
plt.title(f"Predictions for Image")
plt.show()
# Out:
# image 1/1 /home/renile-ai/AI/Plant-Diseases-Detection/potato_late.jpeg: 640x512 9 leafs, 16.7ms
# Speed: 41.9ms preprocess, 16.7ms inference, 30.5ms postprocess per image at shape (1, 3, 640, 512)

# %%
from ultralytics import YOLO
from IPython.display import display
from PIL import Image

model = YOLO("/home/renile-ai/AI/Plant-Diseases-Detection/PlantDiseaseDetection.pt")

source = "/home/renile-ai/AI/Plant-Diseases-Detection/potato_late.jpeg"

results = model.predict(
    source=source,
    save=True
)

# Display annotated image
annotated_image = results[0].plot()
display(Image.fromarray(annotated_image))
# Out:
# image 1/1 /home/renile-ai/AI/Plant-Diseases-Detection/potato_late.jpeg: 640x512 1 potato early blight, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /home/renile-ai/AI/Plant-Diseases/runs/detect/predict
# <PIL.Image.Image image mode=RGB size=399x501>
